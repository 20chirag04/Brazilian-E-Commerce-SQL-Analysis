# %%
import pandas as pd
import pymysql

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://root:Chirag04@localhost:3306/olist_ecommerce")

# %%
dataset_dir = [r"D:\Olist-Ecommerce-SQL-Analysis\data\raw\olist_customers_dataset.csv",
               r"D:\Olist-Ecommerce-SQL-Analysis\data\raw\olist_geolocation_dataset.csv",
              r"D:\Olist-Ecommerce-SQL-Analysis\data\raw\olist_order_items_dataset.csv",
              r"D:\Olist-Ecommerce-SQL-Analysis\data\raw\olist_order_payments_dataset.csv",
              r"D:\Olist-Ecommerce-SQL-Analysis\data\raw\olist_order_reviews_dataset.csv",
              r"D:\Olist-Ecommerce-SQL-Analysis\data\raw\olist_orders_dataset.csv",
              r"D:\Olist-Ecommerce-SQL-Analysis\data\raw\olist_products_dataset.csv",
              r"D:\Olist-Ecommerce-SQL-Analysis\data\raw\olist_sellers_dataset.csv",
              r"D:\Olist-Ecommerce-SQL-Analysis\data\raw\product_category_name_translation.csv"]

# %%
cust_df = pd.read_csv(customer_dir)
geo_df = pd.read_csv(geolocation_dir)

# %%
dataset_name = ['customers',
               'geolocation',
               'order_items',
               'order_payments',
               'order_reviews',
               'orders',
                'products',
                'sellers',
                'product_category_translation'
               ]

# %%
## Without Foreign Keys
for i,x in zip(dataset_dir,dataset_name):
    pd.read_csv(i).to_sql(x,con = engine,if_exists = 'replace', index = False)

# %%
# import pymysql
# from sqlalchemy import create_engine
# engine = ("mysql+pymysql://root:Chirag04@localhost:3306/store")
# df.to_sql('table_name',con = engine,inplace = 'replace',index = False)

# %%
# Out:
#       order_id product_id  quantity_ordered
# 0         1000       7713                 6
# 1         1001       3690                 3
# 2         1001       4925                 8
# 3         1001       7713                 5
# 4         1001       74dd                 3
# ...        ...        ...               ...
# 1075      1548       1c15                 4
# 1076      1549       2e2e                 4
# 1077      1549       176f                 3
# 1078      1549       4b18                 6
# 1079      1549       3128                 8
#
# [1080 rows x 3 columns]
